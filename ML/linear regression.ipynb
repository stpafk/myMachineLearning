# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.DataFrame({
    'area': [2600, 3000, 3200, 3600, 4000],
    'price': [550000, 565000, 610000, 680000, 725000]
})

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')
plt.savefig('books_read.png')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
#reg.coef_

reg.intercept_
#price = m * area + b
# Out:
# 180616.43835616432

# %%
houses = pd.DataFrame({
    'area': [3000, 4000, 5200, 7600, 9000],
})

p = reg.predict(houses)
houses['prices'] = p
houses
# Out:
#    area        prices
# 0  3000  5.879795e+05
# 1  4000  7.237671e+05
# 2  5200  8.867123e+05
# 3  7600  1.212603e+06
# 4  9000  1.402705e+06

# %%
canada = pd.read_csv('canada_per_capita_income.csv')
canada.rename(columns={'per capita income (US$)': 'pci'}, inplace=True)

plt.xlabel('year')
plt.ylabel('GDP')
plt.scatter(canada.year, canada.pci, color='red', marker='+')
plt.plot(canada.year, reg.predict(canada[['year']]), color='blue')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-7acf8d4511c2> in <module>
# ----> 1 canada = pd.read_csv('canada_per_capita_income.csv')
#       2 canada.rename(columns={'per capita income (US$)': 'pci'}, inplace=True)
#       3
#       4 plt.xlabel('year')
#       5 plt.ylabel('GDP')
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
reg.fit(canada[['year']], canada.pci)
reg.predict([[2021]])

# %%
br = pd.read_csv('brasil.csv')
br.rename(columns={'GDP': 'gdp'}, inplace=True)
br['gdp'] = br['gdp'].str.replace(',', '.')
br['gdp'] = br['gdp'].astype('float64')

plt.xlabel('Year')
plt.ylabel('GDP')
plt.scatter(br.YEAR, br.gdp, color='red', marker='+')
plt.plot(br.YEAR, reg.predict(br[['YEAR']]), color='blue')

# %%
reg.fit(br[['YEAR']], br.gdp)
reg.predict([[2040]])
